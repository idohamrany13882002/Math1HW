# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exc.1

# %% [markdown]
# x + y = 4
#
# -->
# ## y = -x + 4

# %% [markdown]
# 2x - y = 2
#
# -->
# ## y = 2x - 2

# %% [markdown]
# Do to having 2 different slopes there is 1 point of intercept

# %%
x = np.linspace(-1,5)
y1 = -x + 4
y2 = 2*x - 2

plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='x + y = 4', color='blue')
plt.plot(x, y2, label='2x - y = 2', color='red')
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Exc. 2

# %% [markdown]
# 2x + y = 6
#
# -->
# ## y = -2x + 6

# %% [markdown]
# 4x + 2y = 10
#
# -->
#
# 2y = -4x + 10 /:2
#
# -->
# ## y = -2x + 5

# %% [markdown]
# Do to having the same slop and 2 different Y axic intercept point the two line are parallels and have no point of intercept between them

# %%
x = np.linspace(-1,5)
y1 = -2*x + 6
y2 = -2*x + 5

plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='x + y = 4', color='blue')
plt.plot(x, y2, label='2x - y = 2', color='red')
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Exc. 3

# %% [markdown]
# The two equations have the same slope and Y axis intercept point therefore they are the same line

# %% [markdown]
# 3x + 2y = 12
#
# -->
#
# 2y = -3x + 12 /:2
#
# -->
# ## y = -1.5x + 6

# %% [markdown]
# 6x + 4y = 24
#
# -->
#
# 4y = -6x + 24 /:4
#
# -->
# ## y = -1.5x + 6

# %%
x = np.linspace(-1,5)
y1 = -1.5*x + 6
y2 = -1.5*x + 6

plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='x + y = 4', color='blue')
plt.plot(x, y2, label='2x - y = 2', color='red')
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()
